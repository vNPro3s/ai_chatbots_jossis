# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from aux_functions import get_completion

env_path = os.path.join(os.getcwd(), '.env')
# loading the environment variables
load_dotenv(dotenv_path=env_path)
print("Everything is fine :-)")
# Out:
# Everything is fine :-)

# %%
# creating base OpenAI client
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))
print("Client created successfully")
print(client)
# Out:
# Client created successfully
# ...

# %%
text = """
Prompt design is an essential skill when working with AI models like GPT-3 and GPT-4. \
It focuses on creating specific inputs that effectively guide the model's responses. \
Crafting clear and detailed prompts helps improve the accuracy, relevance, and creativity of the output generated by the AI. \
The goal is to communicate the task to the AI in a way that minimizes ambiguity and enhances the model's understanding of the context. \

Effective prompt design involves being concise while providing enough information to set the boundaries for the AI's response. \
Including relevant context allows the AI to focus on the task and produce more precise answers. \
By refining the wording and structure of the prompt, users can significantly influence the quality of the output. \

Another important aspect of prompt design is recognizing the AI model's strengths and weaknesses. \
Understanding these characteristics allows users to adjust their prompts to align better with the model's capabilities. \
Experimentation and iteration are often required to determine the most effective way to phrase a prompt. \
This iterative process helps identify which types of prompts yield the best results for specific tasks or queries. \

Ultimately, the effectiveness of AI-generated responses is heavily dependent on the quality of the prompts provided. \
Investing time in designing thoughtful and precise prompts can lead to more useful and insightful AI outputs. \
"""

# %%
prompt = f"""
Summarize the following text in three bacticles:

```{text}```
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# 1. **Importance of Prompt Design**: Crafting clear and detailed prompts is crucial for guiding AI models like GPT-3 and GPT-4, enhancing the accuracy, relevance, and creativity of their responses by minimizing ambiguity and improving context understanding.
#
# 2. **Effective Techniques**: Successful prompt design involves being concise yet informative, providing relevant context, and refining wording and structure to influence the quality of AI outputs significantly.
#
# 3. **Iterative Process and Model Understanding**: Recognizing the AI model's strengths and weaknesses, and engaging in experimentation and iteration, are key to developing effective prompts that yield the best results for specific tasks or queries.

# %%
prompt = f"""
Summarize the following text in three bacticles. Use list as the summarization model, and ensure that each list item is a compete one sentence.

```{text}```
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# 1. Prompt design is crucial for guiding AI models like GPT-3 and GPT-4 to produce accurate, relevant, and creative responses by crafting clear and detailed inputs.
# 2. Effective prompt design requires being concise while providing enough context to set boundaries and improve the AI's understanding of the task.
# 3. Recognizing the AI model's strengths and weaknesses and iterating on prompt phrasing can significantly enhance the quality of AI-generated responses.

# %%
prompt = f"""
How do I calcualte mean and standard deviation in Excel? Limit the response to 100 words.
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# To calculate the mean in Excel, use the `AVERAGE` function. For example, `=AVERAGE(A1:A10)` calculates the mean of values in cells A1 to A10. To calculate the standard deviation, use the `STDEV.P` function for the entire population or `STDEV.S` for a sample. For example, `=STDEV.P(A1:A10)` or `=STDEV.S(A1:A10)`. These functions provide the standard deviation of the values in the specified range.

# %%
prompt = f"""
I have a column for monthly customer spending named “MNTH_SPENDING"\
Explain how to calculate in Excel the mean spending shown in cell “AVG” \
and the corresponding standard deviation in the cell called “STD.”

Limit the response to 100 words in the list format.
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# 1. Click on the cell named "AVG."
# 2. Enter the formula: `=AVERAGE(MNTH_SPENDING)`
# 3. Press Enter to calculate the mean spending.
# 4. Click on the cell named "STD."
# 5. Enter the formula: `=STDEV.P(MNTH_SPENDING)` for population standard deviation or `=STDEV.S(MNTH_SPENDING)` for sample standard deviation.
# 6. Press Enter to calculate the standard deviation.

# %%
review = """
I recently purchased the X500 Wireless Headphones from SoundTech Innovations, \
and I am thoroughly impressed. The sound quality is exceptional, and the battery \
life exceeds my expectations. The comfortable fit makes them perfect for long \
listening sessions. Highly recommend these headphones for anyone in need of top-notch audio performance.
"""

# %%
prompt = f""" Analyze the review  in the angle bracket so it \
can be classified as positive, negative, or neutral reviews.
Only print the classification of the review without any additional information.

<{review}>
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# Positive

# %%
review = """
I recently purchased the X500 Wireless Headphones from SoundTech Innovations, \
and I am thoroughly impressed. The sound quality is exceptional, and the battery \
life exceeds my expectations. The comfortable fit makes them perfect for long \
listening sessions. Highly recommend these headphones for anyone in need of top-notch audio performance.
"""

# %%
prompt = f""" Analyze the review  in the angle bracket and provide output in the form \
of JSON file (key: values) with the following keys and values definitions:

product: name of the product (if not known, write unknown)
brand: name of the brand (if not known, write unknown)
review: review summaries (if the review is longer than 300 words, otherwise original review)
opinion: positive, negative or neutral (if not possible to detect, write unable to detect)

<{review}>
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# ```json
# {
#   "product": "X500 Wireless Headphones",
#   "brand": "SoundTech Innovations",
#   "review": "I recently purchased the X500 Wireless Headphones from SoundTech Innovations, and I am thoroughly impressed. The sound quality is exceptional, and the battery life exceeds my expectations. The comfortable fit makes them perfect for long listening sessions. Highly recommend these headphones for anyone in need of top-notch audio performance.",
#   "opinion": "positive"
# }
# ```

# %% [markdown]
# # Checking the conditions

# %%
text = f"""
The sun is shining brightly today, and the birds are \
singing. It's a beautiful day to go for a \
walk in the park. The flowers are blooming, and the \
trees are swaying gently in the breeze. People \
are out and about, enjoying the lovely weather. \
Some are having picnics, while others are playing \
games or simply relaxing on the grass. It's a \
perfect day to spend time outdoors and appreciate the \
beauty of nature.
"""

# %%
prompt = f"""
You will be provided with text delimited by triplw backticks. \n
If it contains a sequence of instructions, \
re-write those instructions in the following format: \

Step 1 - ...
Step 2 - ...
---
Step N - ...

If the text does not contain a sequence of instructions, \
then simply write: \

`No steps found in the text.`

```{text}```
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# `No steps found in the text.`

# %% [markdown]
# # Teaching from examples

# %%
prompt = f"""
Your task is to answer in the consistent style no longer than 100 words. \

<child>: teach me about patience 
<parent>: The river that carves the deepest \
    valley flows from modest spring; the \
    grandes symphony originates from a single note; \
    the most intricate tapestry begins with a single thread. \

<child>: teach me about love

"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# <parent>: Love is like a garden that needs care and attention. It starts with a seed of kindness, grows with acts of understanding, and blossoms with trust and respect. Just as a gardener tends to each plant, we must nurture our relationships with patience and compassion.

# %% [markdown]
# # Give time to think - T1 define steps

# %%
text = f"""
In a charming village, siblings Jack and Jill set out on \
a quest to fetch water from a hilltop \
well. As they climbed, singing joyfully, fortune \
struck—Jack tripped on a stone and tumbled \
down the hill, with Jill following suit. \
Though slightly battered, the pair returned home to \
comforting embraces. Despite the mishap, \
their adventurous spirits remained undimmed, and they \
continued exploring with delight.
"""

# %%
# example 1
prompt_1 = f"""
Perform the following actions: 
1 - Summarize the following text delimited by triple \
backticks with 1 sentence.
2 - Translate the summary into French.
3 - List each name in the French summary.
4 - Output a json object that contains the following \
keys: french_summary, num_names.

Separate your answers with line breaks.

Text:
```{text}```
"""

# %%
response = get_completion(prompt_1, client)
print(response)
# Out:
# 1 - Siblings Jack and Jill went on an adventure to fetch water, faced a mishap, but returned home safely and continued their explorations with joy.
#
# 2 - Les frères et sœurs Jack et Jill sont partis à l'aventure pour chercher de l'eau, ont rencontré un incident, mais sont rentrés chez eux en toute sécurité et ont continué leurs explorations avec joie.
#
# 3 - Jack, Jill
#
# 4 -
# ```json
# {
#   "french_summary": "Les frères et sœurs Jack et Jill sont partis à l'aventure pour chercher de l'eau, ont rencontré un incident, mais sont rentrés chez eux en toute sécurité et ont continué leurs explorations avec joie.",
#   "num_names": 2
# }
# ```

# %% [markdown]
# ## T2 Specify output format

# %%
prompt_2 = f"""
Your task is to perform the following actions: 
1 - Summarize the following text delimited by 
  <> with 1 sentence.
2 - Translate the summary into French.
3 - List each name in the French summary.
4 - Output a json object that contains the 
  following keys: french_summary, num_names.

Use the following format:
Text: <text to summarize>
Summary: <summary>
Translation: <summary translation>
Names: <list of names in summary>
Output JSON: <json with summary and num_names>

Text: <{text}>
"""

# %%
response  = get_completion(prompt_2, client)
print(response)
# Out:
# Summary: In a charming village, siblings Jack and Jill set out to fetch water from a hilltop well, but Jack tripped and tumbled down the hill with Jill following, yet they returned home slightly battered but undeterred in their adventurous spirits.
#
# Translation: Dans un charmant village, les frères et sœurs Jack et Jill sont partis chercher de l'eau à un puits au sommet d'une colline, mais Jack a trébuché et est tombé de la colline avec Jill le suivant, pourtant ils sont rentrés chez eux légèrement meurtris mais sans être découragés dans leur esprit d'aventure.
#
# Names: [Jack, Jill]
#
# Output JSON: {
#   "french_summary": "Dans un charmant village, les frères et sœurs Jack et Jill sont partis chercher de l'eau à un puits au sommet d'une colline, mais Jack a trébuché et est tombé de la colline avec Jill le suivant, pourtant ils sont rentrés chez eux légèrement meurtris mais sans être découragés dans leur esprit d'aventure.",
#   "num_names": 2
# }

# %% [markdown]
# ## T3 - instruct model to work on its own solution before final conclusion

# %%
prompt = f"""
Determine if the student's solution is correct or not.

Question:
I'm building a solar power installation and I need \
 help working out the financials. 
- Land costs $100 / square foot
- I can buy solar panels for $250 / square foot
- I negotiated a contract for maintenance that will cost \
me a flat $100k per year, and an additional $10 / square \
foot
What is the total cost for the first year of operations 
as a function of the number of square feet.

Student's Solution:
Let x be the size of the installation in square feet.
Costs:
1. Land cost: 100x
2. Solar panel cost: 250x
3. Maintenance cost: 100,000 + 100x
Total cost: 100x + 250x + 100,000 + 100x = 450x + 100,000
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# The student's solution is almost correct, but there is a small mistake in the maintenance cost calculation. The maintenance cost should be $100,000 plus $10 per square foot, not $100 per square foot.
#
# Let's correct the solution step-by-step:
#
# 1. **Land cost**: $100 per square foot
#    \[
#    \text{Land cost} = 100x
#    \]
#
# 2. **Solar panel cost**: $250 per square foot
#    \[
#    \text{Solar panel cost} = 250x
#    \]
#
# 3. **Maintenance cost**: $100,000 per year plus $10 per square foot
#    \[
#    \text{Maintenance cost} = 100,000 + 10x
#    \]
#
# Now, summing up all the costs:
#
# \[
# \text{Total cost} = \text{Land cost} + \text{Solar panel cost} + \text{Maintenance cost}
# \]
# \[
# \text{Total cost} = 100x + 250x + 100,000 + 10x
# \]
# \[
# \text{Total cost} = 360x + 100,000
# \]
#
# So, the correct total cost for the first year of operations as a function of the number of square feet \( x \) is:
#
# \[
# 360x + 100,000
# \]
#
# ...

# %%
# improvement

prompt = f"""
Your task is to determine if the student's solution \
is correct or not.
To solve the problem do the following:
- First, work out your own solution to the problem including the final total. 
- Then compare your solution to the student's solution \
and evaluate if the student's solution is correct or not. 
Don't decide if the student's solution is correct until 
you have done the problem yourself.

Use the following format for output:
Question:
```
question here

```
Student's solution:
```
student's solution here
```
Your solution:
```
steps to work out the solution and your solution here
```
Is the student's solution the same as actual solution \
just calculated:
```
yes or no
```
Student grade:
```
correct or incorrect
```

Question:
```
I'm building a solar power installation and I need help \
working out the financials. 
- Land costs $100 / square foot
- I can buy solar panels for $250 / square foot
- I negotiated a contract for maintenance that will cost \
me a flat $100k per year, and an additional $10 / square \
foot
What is the total cost for the first year of operations \
as a function of the number of square feet.
``` 
Student's solution:
```
Let x be the size of the installation in square feet.
Costs:
1. Land cost: 100x
2. Solar panel cost: 250x
3. Maintenance cost: 100,000 + 100x
Total cost: 100x + 250x + 100,000 + 100x = 450x + 100,000
```
Your solution:
"""

# %%
response = get_completion(prompt, client)
print(response)
# Out:
# ```
# Let x be the size of the installation in square feet.
# Costs:
# 1. Land cost: 100x
# 2. Solar panel cost: 250x
# 3. Maintenance cost: 100,000 + 10x
# Total cost: 100x + 250x + 100,000 + 10x = 360x + 100,000
# ```
# Is the student's solution the same as actual solution just calculated:
# ```
# no
# ```
# Student grade:
# ```
# incorrect
# ```
